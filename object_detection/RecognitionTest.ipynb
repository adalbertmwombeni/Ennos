# %%
# !pip install -U --pre tensorflow=="2.2.0"
# Out:
# Requirement already up-to-date: tensorflow==2.2.0 in c:\users\mwomada\miniconda3\envs\tensorflow_env\lib\site-packages (2.2.0)
# ...

# %%
import os
import pathlib

# Clone the tensorflow models repository if it doesn't already exist
if "models" in pathlib.Path.cwd().parts:
  while "models" in pathlib.Path.cwd().parts:
    os.chdir('..')
elif not pathlib.Path('models').exists():
  # !git clone --depth 1 https://github.com/tensorflow/models

# %%
# Install the Object Detection API
#%%bash
#cd models/research/
#protoc object_detection/protos/*.proto --python_out=.
#cp object_detection/packages/tf2/setup.py .
#python -m pip install .
#pwd

# %%
#run model builder test
# !python C:/Users/Mwomada/Desktop/models/research/object_detection/builders/model_builder_tf2_test.py
# Out:
# 2020-10-28 22:06:48.643390: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_101.dll'; dlerror: cudart64_101.dll not found
# 2020-10-28 22:06:48.643892: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Running tests under Python 3.7.7: C:\Users\Mwomada\Miniconda3\envs\tensorflow_env\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model
# 2020-10-28 22:06:52.132310: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2020-10-28 22:06:52.132782: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: UNKNOWN ERROR (303)
# 2020-10-28 22:06:52.137568: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DEFTCNX3202
# ...

# %% [markdown]
# # Export model inference graph

# %%
with open('C:/Users/Mwomada/Miniconda3/envs/tensorflow_env/Lib/site-packages/tensorflow/python/keras/utils/tf_utils.py') as f:
    tf_utils = f.read()

with open('C:/Users/Mwomada/Miniconda3/envs/tensorflow_env/Lib/site-packages/tensorflow/python/keras/utils/tf_utils.py', 'w') as f:
  # Set labelmap path
  throw_statement = "raise TypeError('Expected Operation, Variable, or Tensor, got ' + str(x))"
  tf_utils = tf_utils.replace(throw_statement, "if not isinstance(x, str):" + throw_statement)
  f.write(tf_utils)
# Out:
# I1028 22:07:26.286533 14936 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet EfficientNet backbone version: efficientnet-b5
# I1028 22:07:26.286533 14936 ssd_efficientnet_bifpn_feature_extractor.py:145] EfficientDet BiFPN num filters: 288
# I1028 22:07:26.286533 14936 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num iterations: 7
# I1028 22:07:26.292516 14936 efficientnet_model.py:148] round_filter input=32 output=48
# I1028 22:07:26.335401 14936 efficientnet_model.py:148] round_filter input=32 output=48
# I1028 22:07:26.336402 14936 efficientnet_model.py:148] round_filter input=16 output=24
# I1028 22:07:26.746270 14936 efficientnet_model.py:148] round_filter input=16 output=24
# I1028 22:07:26.746270 14936 efficientnet_model.py:148] round_filter input=24 output=40
# I1028 22:07:27.674648 14936 efficientnet_model.py:148] round_filter input=24 output=40
# I1028 22:07:27.674648 14936 efficientnet_model.py:148] round_filter input=40 output=64
# ...

# %%
model_dir = 'training/'
pipeline_config_path = 'model_config.config'

# %%
batch_size = 16
num_steps = 8000
num_eval_steps = 1000

# %%
# Install Kaggle API
# !pip install -q kaggle
# !pip install -q kaggle-cli
# Out:
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Mwomada\Miniconda3\envs\tensorflow_env\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Mwomada\\AppData\\Local\\Temp\\pip-install-7uao5p5q\\lxml\\setup.py'"'"'; __file__='"'"'C:\\Users\\Mwomada\\AppData\\Local\\Temp\\pip-install-7uao5p5q\\lxml\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Mwomada\AppData\Local\Temp\pip-wheel-5j55c_50'
#        cwd: C:\Users\Mwomada\AppData\Local\Temp\pip-install-7uao5p5q\lxml\
#   Complete output (97 lines):
#   Building lxml version 4.0.0.
#   Building without Cython.
#   ERROR: b'Der Befehl "xslt-config" ist entweder falsch geschrieben oder\r\nkonnte nicht gefunden werden.\r\n'
#   ** make sure the development packages of libxml2 and libxslt are installed **
#
# ...

# %%
# !wget https://raw.githubusercontent.com/TannerGilbert/Tensorflow-Object-Detection-API-Train-Model/master/generate_tfrecord.py
# Out:
# --2020-10-28 22:15:44--  https://raw.githubusercontent.com/TannerGilbert/Tensorflow-Object-Detection-API-Train-Model/master/generate_tfrecord.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.112.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.112.133|:443... connected.
# ERROR: cannot verify raw.githubusercontent.com's certificate, issued by 'CN=DigiCert SHA2 High Assurance Server CA,OU=www.digicert.com,O=DigiCert Inc,C=US':
#   Unable to locally verify the issuer's authority.
# To connect to raw.githubusercontent.com insecurely, use `--no-check-certificate'.

# %%
# edit configuration file (from https://colab.research.google.com/drive/1sLqFKVV94wm-lglFq_0kGo2ciM0kecWD)

import re

with open(base_config_path) as f:
    config = f.read()

with open('model_config.config', 'w') as f:
  
  # Set labelmap path
  config = re.sub('label_map_path: ".*?"', 
             'label_map_path: "{}"'.format(labelmap_path), config)
  
  # Set fine_tune_checkpoint path
  config = re.sub('fine_tune_checkpoint: ".*?"',
                  'fine_tune_checkpoint: "{}"'.format(fine_tune_checkpoint), config)
  
  # Set train tf-record file path
  config = re.sub('(input_path: ".*?)(PATH_TO_BE_CONFIGURED/train)(.*?")', 
                  'input_path: "{}"'.format(train_record_path), config)
  
  # Set test tf-record file path
  config = re.sub('(input_path: ".*?)(PATH_TO_BE_CONFIGURED/val)(.*?")', 
                  'input_path: "{}"'.format(test_record_path), config)
  
  # Set number of classes.
  config = re.sub('num_classes: [0-9]+',
                  'num_classes: {}'.format(4), config)
   # Set batch size
  config = re.sub('batch_size: [0-9]+',
                  'batch_size: {}'.format(batch_size), config)
  
  # Set training steps
  config = re.sub('num_steps: [0-9]+',
                  'num_steps: {}'.format(num_steps), config)
  
  # Set fine-tune checkpoint type to detection
  config = re.sub('fine_tune_checkpoint_type: "classification"', 
             'fine_tune_checkpoint_type: "{}"'.format('detection'), config)
  
  f.write(config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-5d2f01f9e6fc> in <module>
#       3 import re
#       4
# ----> 5 with open(base_config_path) as f:
#       6     config = f.read()
#       7
#
# NameError: name 'base_config_path' is not defined
